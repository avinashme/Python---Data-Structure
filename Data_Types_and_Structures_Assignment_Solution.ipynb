# %% [markdown]
# # Data Types and Structures Assignment Solution

# %% [markdown]
# ## Q1
# **Question:** What are data structures, and why are they important?
#
# **Answer:**
#
# Sample concise answer explaining the concept with suitable examples.

# %% [markdown]
# ## Q2
# **Question:** Explain the difference between mutable and immutable data types with examples.
#
# **Answer:**
#
# Sample concise answer explaining the concept with suitable examples.

# %% [markdown]
# ## Q3
# **Question:** What are the main differences between lists and tuples in Python?
#
# **Answer:**
#
# Sample concise answer explaining the concept with suitable examples.

# %% [markdown]
# ## Q4
# **Question:** Describe how dictionaries store data.
#
# **Answer:**
#
# Sample concise answer explaining the concept with suitable examples.

# %% [markdown]
# ## Q5
# **Question:** Why might you use a set instead of a list in Python?
#
# **Answer:**
#
# Sample concise answer explaining the concept with suitable examples.

# %% [markdown]
# ## Q6
# **Question:** What is a string in Python, and how is it different from a list?
#
# **Answer:**
#
# Sample concise answer explaining the concept with suitable examples.

# %% [markdown]
# ## Q7
# **Question:** How do tuples ensure data integrity in Python?
#
# **Answer:**
#
# Sample concise answer explaining the concept with suitable examples.

# %% [markdown]
# ## Q8
# **Question:** What is a hash table, and how does it relate to dictionaries in Python?
#
# **Answer:**
#
# Sample concise answer explaining the concept with suitable examples.

# %% [markdown]
# ## Q9
# **Question:** Can lists contain different data types in Python?
#
# **Answer:**
#
# Sample concise answer explaining the concept with suitable examples.

# %% [markdown]
# ## Q10
# **Question:** Explain why strings are immutable in Python.
#
# **Answer:**
#
# Sample concise answer explaining the concept with suitable examples.

# %% [markdown]
# ## Q11
# **Question:** What advantages do dictionaries offer over lists for certain tasks?
#
# **Answer:**
#
# Sample concise answer explaining the concept with suitable examples.

# %% [markdown]
# ## Q12
# **Question:** Describe a scenario where using a tuple would be preferable over a list.
#
# **Answer:**
#
# Sample concise answer explaining the concept with suitable examples.

# %% [markdown]
# ## Q13
# **Question:** How do sets handle duplicate values in Python?
#
# **Answer:**
#
# Sample concise answer explaining the concept with suitable examples.

# %% [markdown]
# ## Q14
# **Question:** How does the 'in' keyword work differently for lists and dictionaries?
#
# **Answer:**
#
# Sample concise answer explaining the concept with suitable examples.

# %% [markdown]
# ## Q15
# **Question:** Can you modify the elements of a tuple? Why or why not?
#
# **Answer:**
#
# Sample concise answer explaining the concept with suitable examples.

# %% [markdown]
# ## Q16
# **Question:** What is a nested dictionary? Give an example.
#
# **Answer:**
#
# Sample concise answer explaining the concept with suitable examples.

# %% [markdown]
# ## Q17
# **Question:** Describe the time complexity of accessing dictionary elements.
#
# **Answer:**
#
# Sample concise answer explaining the concept with suitable examples.

# %% [markdown]
# ## Q18
# **Question:** When are lists preferred over dictionaries?
#
# **Answer:**
#
# Sample concise answer explaining the concept with suitable examples.

# %% [markdown]
# ## Q19
# **Question:** Why were dictionaries considered unordered? How does this affect retrieval?
#
# **Answer:**
#
# Sample concise answer explaining the concept with suitable examples.

# %% [markdown]
# ## Q20
# **Question:** Difference between list and dictionary in data retrieval.
#
# **Answer:**
#
# Sample concise answer explaining the concept with suitable examples.

# %% [markdown]
# ## Q21
# **Question:** Practical Question 1
#
# **Answer:**

# %%
print("Avinash Kumar")

# %% [markdown]
# ## Q22
# **Question:** Practical Question 2
#
# **Answer:**

# %%
print(len("Hello World"))

# %% [markdown]
# ## Q23
# **Question:** Practical Question 3
#
# **Answer:**

# %%
print("Python Programming"[:3])

# %% [markdown]
# ## Q24
# **Question:** Practical Question 4
#
# **Answer:**

# %%
print("hello".upper())

# %% [markdown]
# ## Q25
# **Question:** Practical Question 5
#
# **Answer:**

# %%
print("I like apple".replace("apple","orange"))

# %% [markdown]
# ## Q26
# **Question:** Practical Question 6
#
# **Answer:**

# %%
print([1,2,3,4,5])

# %% [markdown]
# ## Q27
# **Question:** Practical Question 7
#
# **Answer:**

# %%
l=[1,2,3,4];l.append(10);print(l)

# %% [markdown]
# ## Q28
# **Question:** Practical Question 8
#
# **Answer:**

# %%
l=[1,2,3,4,5];l.remove(3);print(l)

# %% [markdown]
# ## Q29
# **Question:** Practical Question 9
#
# **Answer:**

# %%
l=['a','b','c','d'];print(l[1])

# %% [markdown]
# ## Q30
# **Question:** Practical Question 10
#
# **Answer:**

# %%
l=[10,20,30,40,50];l.reverse();print(l)

# %% [markdown]
# ## Q31
# **Question:** Practical Question 11
#
# **Answer:**

# %%
t=(100,200,300);print(t)

# %% [markdown]
# ## Q32
# **Question:** Practical Question 12
#
# **Answer:**

# %%
t=('red','green','blue','yellow');print(t[-2])

# %% [markdown]
# ## Q33
# **Question:** Practical Question 13
#
# **Answer:**

# %%
t=(10,20,5,15);print(min(t))

# %% [markdown]
# ## Q34
# **Question:** Practical Question 14
#
# **Answer:**

# %%
t=('dog','cat','rabbit');print(t.index('cat'))

# %% [markdown]
# ## Q35
# **Question:** Practical Question 15
#
# **Answer:**

# %%
t=('apple','banana','mango');print('kiwi' in t)

# %% [markdown]
# ## Q36
# **Question:** Practical Question 16
#
# **Answer:**

# %%
s={'a','b','c'};print(s)

# %% [markdown]
# ## Q37
# **Question:** Practical Question 17
#
# **Answer:**

# %%
s={1,2,3,4,5};s.clear();print(s)

# %% [markdown]
# ## Q38
# **Question:** Practical Question 18
#
# **Answer:**

# %%
s={1,2,3,4};s.remove(4);print(s)

# %% [markdown]
# ## Q39
# **Question:** Practical Question 19
#
# **Answer:**

# %%
print({1,2,3}|{3,4,5})

# %% [markdown]
# ## Q40
# **Question:** Practical Question 20
#
# **Answer:**

# %%
print({1,2,3}&{2,3,4})

# %% [markdown]
# ## Q41
# **Question:** Practical Question 21
#
# **Answer:**

# %%
d={'name':'John','age':25,'city':'NY'};print(d)

# %% [markdown]
# ## Q42
# **Question:** Practical Question 22
#
# **Answer:**

# %%
d={'name':'John','age':25};d['country']='USA';print(d)

# %% [markdown]
# ## Q43
# **Question:** Practical Question 23
#
# **Answer:**

# %%
d={'name':'Alice','age':30};print(d['name'])

# %% [markdown]
# ## Q44
# **Question:** Practical Question 24
#
# **Answer:**

# %%
d={'name':'Bob','age':22,'city':'New York'};d.pop('age');print(d)

# %% [markdown]
# ## Q45
# **Question:** Practical Question 25
#
# **Answer:**

# %%
d={'name':'Alice','city':'Paris'};print('city' in d)

# %% [markdown]
# ## Q46
# **Question:** Practical Question 26
#
# **Answer:**

# %%
print([1,2],(3,4),{'a':1})

# %% [markdown]
# ## Q47
# **Question:** Practical Question 27
#
# **Answer:**

# %%
import random
l=[random.randint(1,100) for _ in range(5)];l.sort();print(l)

# %% [markdown]
# ## Q48
# **Question:** Practical Question 28
#
# **Answer:**

# %%
l=['a','b','c','d','e'];print(l[3])

# %% [markdown]
# ## Q49
# **Question:** Practical Question 29
#
# **Answer:**

# %%
d1={'a':1};d2={'b':2};d1.update(d2);print(d1)

# %% [markdown]
# ## Q50
# **Question:** Practical Question 30
#
# **Answer:**

# %%
print(set(['a','b','a','c']))
